# %% [markdown]
# ### Import nessie
# First change system path to nessie src folder. I use ```os.getcwd()``` when working within my nessie directory. You only need to do this if nessie isn't already installed in your environment.

# %%
import os
import sys
sys.path.append(os.getcwd()+ "/src/")

# %% [markdown]
# Then import packages like normal.

# %%
import nesse
import numpy as np
import matplotlib.pyplot as plt
import nabPy as Nab
from tqdm.notebook import tqdm
import pickle

# %% [markdown]
# ### Import events
# Import events from Geant root files, an example file is stored in the nessie config/Events/ directory.

# %%
events_filename = "config/Events/e-_800keV_0inc.root"
Events = nesse.eventsFromG4root(events_filename)

# %% [markdown]
# ### Import Electric Field and Weighting Potential
# Example files can be found in config/Fields/.
# These fields were solved using the Julia SolidStateDetector package. For some reason saving to hdf5 in julia rotates the matrix by 90 degrees relative to what python reads from hdf5 files. Because of this there is a ``` rotate90 ``` paramater that is by default set to ``` True ```. If importing fields from elsewhere this may need to be set to ``` False ```.
#
# When you print Fields or Potentials the size will be shown. These example fields are small to keep the file size small.

# %%
EF_filename = "config/Fields/NessieEF_4e7Linear0-150V_grid.hf"
WP_filename = "config/Fields/NessieWP_4e7Linear0-150V_grid.hf"

Efield=nesse.eFieldFromH5(EF_filename)  
weightingPotential = nesse.weightingPotentialFromH5(WP_filename)

print(weightingPotential,Efield)
# Out:
# Nessie Potential object
#  Name: config\Fields\NessieWP_4e7Linear0-150V_grid
#  Size: (370, 337, 33)
#  Nessie Field object
#  Name: config\Fields\NessieEF_4e7Linear0-150V_grid
#  Size: (378, 345, 39)

# %% [markdown]
# ### Create Simulation
# A basic simulation needs a name, electric field, and weighting potential. Currently we only work with one contact at a time. The field describes the field of the entire detector.
#
# Note: All units are meters, seconds, and Kelvin.

# %%
sim = nesse.Simulation("Example_sim", Efield, weightingPotential)

# %% [markdown]
# #### Set electronics response
# The electronics response is determined from a spice simulation and read from a csv. It is convolved with the induced current from the simulated events to get a final signal. Each simulation has a electronic response associated with it, again only working with one contact at a time here. An example spice file from Dustin's spice simulation is in config/Spice.

# %%
spiceFile= "config/Spice/spice_step_New_1ns.csv"
sim.setElectronicResponse(spiceFile)

# %% [markdown]
# #### Set temperature
# Some detector effects are temperature dependent (e.g. mobility).

# %%
sim.setTemp(125)

# %% [markdown]
# #### Set boundaries
# The boundaries define the region of space that e-h pairs are allowed to propogate in. Bounds are defined as ```[[x0,x1],[y0,y1],[z0,z1]]```. You can define these yourself or pull them from a field or potential as done here. The bounds should not be greater than the electric field or weighting potential bounds. Boundaries need to be set where contacts are. For these fields we used a 2mm thick detector.
#
# Note: If not explicitly set will default to electric field boundaries (which probably has the wrong z bounds)

# %%
ef_bounds = [[axis[0],axis[-1]] for axis in Efield.grid]
bounds = np.stack((ef_bounds[0],ef_bounds[1],[0,0.002]))
sim.setBounds(bounds)

# %% [markdown]
# ### Simulate events
# Now that everything is setup we can simulate events. This will first create e-h pairs and drift the electrons and holes. Then it will calculate the induced current using the drift path and weighting field.
#
# Options:
# - eps: ```Float``` Maximum step length for charge propogation.
# - interp3D: ```Bool``` If true use a cython grid interpolator(fast), if false used the scipy grid interpolator (slow). True by default.
# - diffusion: ```Bool``` Toggles random diffusion of electrons and holes.
# - parallel: ```Bool``` Toggles joblib parralization, on RJ's machine the speed up is small but YMMV.
# - maxPairs: ```Int``` Determine maximum number of e-h pairs to create.
# - more features to come!

# %% [markdown]
# This will take a few minutes

# %%
sim.simulate([Events[0]], eps=1e-4, diffusion=False, dt=1e-9)

#if reloading comment above and uncomment below

#Events = nessie.loadEvents("Events")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 40/40 [00:00<00:00, 1267.36it/s]
# Total quasiparticles: 7644
# 0it [00:00, ?it/s]
# 1it [00:01,  1.01s/it]
# 2it [00:01,  1.57it/s]
# 3it [00:01,  2.05it/s]
# 4it [00:01,  2.44it/s]
# 5it [00:02,  2.73it/s]
# 6it [00:02,  2.94it/s]
# 7it [00:02,  3.11it/s]
# 8it [00:03,  3.22it/s]
# 9it [00:03,  3.31it/s]
# 10it [00:03,  3.35it/s]
# 11it [00:04,  3.38it/s]
# 12it [00:04,  3.43it/s]
# 13it [00:04,  3.46it/s]
# 14it [00:04,  3.49it/s]
# 15it [00:05,  3.51it/s]
# 16it [00:05,  3.49it/s]
# 17it [00:05,  3.47it/s]
# 18it [00:05,  3.47it/s]
# 19it [00:06,  3.46it/s]
# 20it [00:06,  3.49it/s]
# 21it [00:06,  3.52it/s]
# 22it [00:07,  3.54it/s]
# 23it [00:07,  3.56it/s]
# 24it [00:07,  3.54it/s]
# 25it [00:07,  3.54it/s]
# 26it [00:08,  3.55it/s]
# 27it [00:08,  3.56it/s]
# 28it [00:08,  3.59it/s]
# 29it [00:09,  3.61it/s]
# 30it [00:09,  3.62it/s]
# 31it [00:09,  3.63it/s]
# 32it [00:09,  3.61it/s]
# 33it [00:10,  3.56it/s]
# 34it [00:10,  3.56it/s]
# 35it [00:10,  3.57it/s]
# 36it [00:11,  3.57it/s]
# 37it [00:11,  3.60it/s]
# 38it [00:11,  3.62it/s]
# 39it [00:11,  3.54it/s]
# 40it [00:12,  3.59it/s]
# 41it [00:12,  3.62it/s]
# 42it [00:12,  3.63it/s]
# 43it [00:12,  3.63it/s]
# 44it [00:13,  3.54it/s]
# 45it [00:13,  3.57it/s]
# 46it [00:13,  3.60it/s]
# 47it [00:14,  3.59it/s]
# 48it [00:14,  3.62it/s]
# 49it [00:14,  3.50it/s]
# 50it [00:14,  3.47it/s]
# 51it [00:15,  3.44it/s]
# 52it [00:15,  3.51it/s]
# 53it [00:15,  3.57it/s]
# 54it [00:16,  3.61it/s]
# 55it [00:16,  3.59it/s]
# 56it [00:16,  3.62it/s]
# 57it [00:16,  3.64it/s]
# 58it [00:17,  3.64it/s]
# 59it [00:17,  3.66it/s]
# 60it [00:17,  3.60it/s]
# 61it [00:18,  3.57it/s]
# 62it [00:18,  3.61it/s]
# 63it [00:18,  3.62it/s]
# 64it [00:18,  3.64it/s]
# 65it [00:19,  3.63it/s]
# 66it [00:19,  3.63it/s]
# 67it [00:19,  3.53it/s]
# 68it [00:19,  3.59it/s]
# 69it [00:20,  3.56it/s]
# 70it [00:20,  3.60it/s]
# 71it [00:20,  3.64it/s]
# 72it [00:21,  3.68it/s]
# 73it [00:21,  3.61it/s]
# 74it [00:21,  3.52it/s]
# 75it [00:21,  3.48it/s]
# 76it [00:22,  3.50it/s]
# 77it [00:22,  3.57it/s]
# 78it [00:22,  3.62it/s]
# 79it [00:23,  3.67it/s]
# 80it [00:23,  3.68it/s]
# 81it [00:23,  3.70it/s]
# 82it [00:23,  3.72it/s]
# 83it [00:24,  3.76it/s]
# 84it [00:24,  3.77it/s]
# 85it [00:24,  3.79it/s]
# 86it [00:24,  3.79it/s]
# 87it [00:25,  3.81it/s]
# 88it [00:25,  3.81it/s]
# 89it [00:25,  3.79it/s]
# 90it [00:25,  3.77it/s]
# 91it [00:26,  3.78it/s]
# 92it [00:26,  3.75it/s]
# 93it [00:26,  3.74it/s]
# 94it [00:26,  3.75it/s]
# 95it [00:27,  3.77it/s]
# 96it [00:27,  3.77it/s]
# 97it [00:27,  3.79it/s]
# 98it [00:28,  3.79it/s]
# 99it [00:28,  3.76it/s]
# 100it [00:28,  3.78it/s]
# 101it [00:28,  3.79it/s]
# 102it [00:29,  3.79it/s]
# 103it [00:29,  3.80it/s]
# 104it [00:29,  3.81it/s]
# 105it [00:29,  3.82it/s]
# 106it [00:30,  3.80it/s]
# 107it [00:30,  3.81it/s]
# 108it [00:30,  3.76it/s]
# 109it [00:30,  3.80it/s]
# 110it [00:31,  3.82it/s]
# 111it [00:31,  3.79it/s]
# 112it [00:31,  3.81it/s]
# 113it [00:31,  3.77it/s]
# 114it [00:32,  3.80it/s]
# 115it [00:32,  3.82it/s]
# 116it [00:32,  3.85it/s]
# 117it [00:33,  3.80it/s]
# 118it [00:33,  3.82it/s]
# 119it [00:33,  3.82it/s]
# 120it [00:33,  3.83it/s]
# 121it [00:34,  3.87it/s]
# 122it [00:34,  3.86it/s]
# 123it [00:34,  3.87it/s]
# 124it [00:34,  3.88it/s]
# 125it [00:35,  3.89it/s]
# 126it [00:35,  3.90it/s]
# 127it [00:35,  3.90it/s]
# 128it [00:35,  3.85it/s]
# 129it [00:36,  3.87it/s]
# 130it [00:36,  3.89it/s]
# 131it [00:36,  3.93it/s]
# 132it [00:36,  3.94it/s]
# 133it [00:37,  3.98it/s]
# 134it [00:37,  3.90it/s]
# 135it [00:37,  3.86it/s]
# 136it [00:37,  3.86it/s]
# 137it [00:38,  3.89it/s]
# 138it [00:38,  3.94it/s]
# 139it [00:38,  4.00it/s]
# 140it [00:38,  3.98it/s]
# 141it [00:39,  4.00it/s]
# 142it [00:39,  3.90it/s]
# 143it [00:39,  3.97it/s]
# 144it [00:39,  3.97it/s]
# 145it [00:40,  4.03it/s]
# 146it [00:40,  4.07it/s]
# 147it [00:40,  4.04it/s]
# 148it [00:40,  3.94it/s]
# 149it [00:41,  3.91it/s]
# 150it [00:41,  3.98it/s]
# 151it [00:41,  3.98it/s]
# 152it [00:41,  3.95it/s]
# 153it [00:42,  3.87it/s]
# 154it [00:42,  3.93it/s]
# 155it [00:42,  3.99it/s]
# 156it [00:42,  4.00it/s]
# 157it [00:43,  3.99it/s]
# 158it [00:43,  4.00it/s]
# 159it [00:43,  3.96it/s]
# 160it [00:43,  3.93it/s]
# 161it [00:44,  3.95it/s]
# 162it [00:44,  4.00it/s]
# 163it [00:44,  3.97it/s]
# 164it [00:44,  4.01it/s]
# 165it [00:45,  4.08it/s]
# 166it [00:45,  4.11it/s]
# 167it [00:45,  4.12it/s]
# 168it [00:45,  4.15it/s]
# 169it [00:46,  4.17it/s]
# 170it [00:46,  4.14it/s]
# 171it [00:46,  4.18it/s]
# 172it [00:46,  4.22it/s]
# 173it [00:47,  4.26it/s]
# 174it [00:47,  4.18it/s]
# 175it [00:47,  4.22it/s]
# 176it [00:47,  4.24it/s]
# 177it [00:48,  4.03it/s]
# 178it [00:48,  4.12it/s]
# 179it [00:48,  4.15it/s]
# 180it [00:48,  4.16it/s]
# 181it [00:49,  4.10it/s]
# 182it [00:49,  4.18it/s]
# 183it [00:49,  4.26it/s]
# 184it [00:49,  4.32it/s]
# 185it [00:49,  4.31it/s]
# 186it [00:50,  4.32it/s]
# 187it [00:50,  4.37it/s]
# 188it [00:50,  4.38it/s]
# 189it [00:50,  4.36it/s]
# 190it [00:51,  4.37it/s]
# 191it [00:51,  4.42it/s]
# 192it [00:51,  4.45it/s]
# 193it [00:51,  4.45it/s]
# 194it [00:51,  4.37it/s]
# 195it [00:52,  4.42it/s]
# 196it [00:52,  4.45it/s]
# 197it [00:52,  4.49it/s]
# 198it [00:52,  4.51it/s]
# 199it [00:53,  4.24it/s]
# 200it [00:53,  4.23it/s]
# 201it [00:53,  4.15it/s]
# 202it [00:53,  4.13it/s]
# 203it [00:54,  4.25it/s]
# 204it [00:54,  4.33it/s]
# 205it [00:54,  4.35it/s]
# 206it [00:54,  4.33it/s]
# 207it [00:54,  4.45it/s]
# 208it [00:55,  4.55it/s]
# 209it [00:55,  4.61it/s]
# 210it [00:55,  4.63it/s]
# 211it [00:55,  4.65it/s]
# 212it [00:56,  4.72it/s]
# 213it [00:56,  4.80it/s]
# 214it [00:56,  4.76it/s]
# 215it [00:56,  4.85it/s]
# 216it [00:56,  4.91it/s]
# 217it [00:57,  5.10it/s]
# 218it [00:57,  5.17it/s]
# 219it [00:57,  5.32it/s]
# 220it [00:57,  5.51it/s]
# 221it [00:57,  5.48it/s]
# 222it [00:57,  5.62it/s]
# 223it [00:58,  5.49it/s]
# 224it [00:58,  5.68it/s]
# 225it [00:58,  5.75it/s]
# 226it [00:58,  5.81it/s]
# 227it [00:58,  5.81it/s]
# 228it [00:58,  5.85it/s]
# 229it [00:59,  5.70it/s]
# 230it [00:59,  5.83it/s]
# 231it [00:59,  5.69it/s]
# 232it [00:59,  5.77it/s]
# 233it [00:59,  5.87it/s]
# 234it [00:59,  5.85it/s]
# 235it [01:00,  5.82it/s]
# 236it [01:00,  5.94it/s]
# 237it [01:00,  5.96it/s]
# 238it [01:00,  5.78it/s]
# 239it [01:00,  5.84it/s]
# 240it [01:00,  5.86it/s]
# 241it [01:01,  5.91it/s]
# 242it [01:01,  5.96it/s]
# 243it [01:01,  5.98it/s]
# 244it [01:01,  6.02it/s]
# 245it [01:01,  5.93it/s]
# 246it [01:01,  5.95it/s]
# 247it [01:02,  5.96it/s]
# 248it [01:02,  5.98it/s]
# 249it [01:02,  6.01it/s]
# 250it [01:02,  5.85it/s]
# 251it [01:02,  5.80it/s]
# 252it [01:03,  5.92it/s]
# 253it [01:03,  5.84it/s]
# 254it [01:03,  5.90it/s]
# 255it [01:03,  5.98it/s]
# 256it [01:03,  6.01it/s]
# 257it [01:03,  6.04it/s]
# 258it [01:04,  6.02it/s]
# 259it [01:04,  6.04it/s]
# 260it [01:04,  6.01it/s]
# 261it [01:04,  5.87it/s]
# 262it [01:04,  5.70it/s]
# 263it [01:04,  5.77it/s]
# 264it [01:05,  5.79it/s]
# 265it [01:05,  5.82it/s]
# 266it [01:05,  5.86it/s]
# 267it [01:05,  5.81it/s]
# 268it [01:05,  5.91it/s]
# 269it [01:05,  5.97it/s]
# 270it [01:06,  6.01it/s]
# 271it [01:06,  6.01it/s]
# 272it [01:06,  6.05it/s]
# 273it [01:06,  6.00it/s]
# 274it [01:06,  5.92it/s]
# 275it [01:06,  5.87it/s]
# 276it [01:07,  5.95it/s]
# 277it [01:07,  5.91it/s]
# 278it [01:07,  5.90it/s]
# 279it [01:07,  6.10it/s]
# 280it [01:07,  6.33it/s]
# 281it [01:07,  6.63it/s]
# 282it [01:07,  7.12it/s]
# 283it [01:08,  7.72it/s]
# 284it [01:08,  7.96it/s]
# 285it [01:08,  8.28it/s]
# 286it [01:08,  8.72it/s]
# 287it [01:08,  8.99it/s]
# 288it [01:08,  9.05it/s]
# 290it [01:08,  9.61it/s]
# 292it [01:08, 10.11it/s]
# 294it [01:09, 10.35it/s]
# 296it [01:09, 10.62it/s]
# 298it [01:09, 11.01it/s]
# 300it [01:09, 11.15it/s]
# 302it [01:09, 11.48it/s]
# 304it [01:09, 12.06it/s]
# 306it [01:10, 12.59it/s]
# 308it [01:10, 12.78it/s]
# 310it [01:10, 13.40it/s]
# 312it [01:10, 13.95it/s]
# 314it [01:10, 14.61it/s]
# 316it [01:10, 15.00it/s]
# 318it [01:10, 15.48it/s]
# 320it [01:11, 16.12it/s]
# 322it [01:11, 16.56it/s]
# 324it [01:11, 17.40it/s]
# 327it [01:11, 18.83it/s]
# 330it [01:11, 20.27it/s]
# 333it [01:11, 21.55it/s]
# 336it [01:11, 22.23it/s]
# 100%|██████████| 1/1 [01:11<00:00, 71.97s/it]
# 342it [01:11,  4.75it/s]

# %% [markdown]
# simulate only simulate the electron and hole trajectories, you need to then convert that to an induced current using the code below.

# %%
sim.setWeightingField()
sim.calculateInducedCurrent([Events[0]], 1e-10)
sim.calculateElectronicResponse([Events[0]])

# %% [markdown]
# That took a while so you will probably want to save the results. There are two ways to that:
# - save the whole event object using ```saveEvents```
# - save just the induced current using ```saveEventNabPy```
#
# The latter also is provided a ``dt`` and ```length``` for downsampling and returns the downsampled signal. The whole event is a lot of data, so we recommend just saving the induced current when possible.

# %%
nabPy_event0 = nesse.saveEventsNabPy([Events[0]], "nabPy_event0",dt=4e-9, length=7000) 
#same dt and length as manitoba data

# %%
#nessie.saveEvents(Events, "Events")

# %% [markdown]
# ### Plotting
# We can plot the final signals

# %%
nesse.plot_signal(Events[0])

# %% [markdown]
# We can also plot the induced current before the electronics

# %%
nesse.plot_current(Events[0])

# %% [markdown]
# You can also plot the e-h drift paths. Plotting all pairs would take a long time, so I've plotted just the first 10 here.

# %%
nesse.plot_event_drift(Events[0], bounds, pairs=10)

# %% [markdown]
# plotting for fields and potentials is included in nessie

# %%
nesse.plot_field_lines(sim.electricField,x_plane=True, density=2, show_plot=True, log=False)

# %%
nesse.plot_potential(sim.weightingPotential)

# %% [markdown]
# ### nabPy Analysis
# With the event downsampled we can now analyze it using nabPy.
# Lets first zoom in on the rising edge.

# %%
plt.plot(-nabPy_event0[0])
plt.xlim(3400,3600)
plt.show()

# %% [markdown]
# Since this is already a numpy array we can use nabPy analsysis functions out of the box. For example we can get the risetimes:

# %%
Nab.basicFunctions.extractRiseTimes(-nabPy_event0,low=0.1,high=0.9)
# Out:
# array([34.])

# %% [markdown]
# recall we used a 4ns time step so this corresponds to a 52 ns risetime, which is reasonable.
#
# other nabPy analsysis functions work too

# %%
Nab.basicFunctions.extractDecayRate(-nabPy_event0)
# Out:
# array([1264.8134], dtype=float32)

# %%
Nab.basicFunctions.applyTrapFilter(-nabPy_event0, 1250,50,1250)
# Out:
# (array([2.23043314e-05]), array([3352.5]))
